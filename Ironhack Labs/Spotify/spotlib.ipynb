# %%
import access
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
access.c_id
# Out:
# '27b10e1918a0404cb6fb89747bc014a9'

# %%
access.c_se
# Out:
# '44f7ab6ca66f47dbae7e8ff538d3e805'

# %%
c_id ='27b10e1918a0404cb6fb89747bc014a9'
c_se = '44f7ab6ca66f47dbae7e8ff538d3e805'

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=c_id, client_secret=c_se))

# %%
sp.search ("Nizi19", market= "DE")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Nizi19&type=track&market=DE&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#        'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#        'id': '4LwRgSkj7AJJTKLnEaHjMv',
#        'name': 'Lucio101',
#        'type': 'artist',
#        'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#        'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#        'id': '2IVvZIe3P9BMuCI6h48Bjg',
#        'name': 'Nizi19',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1YydmO6Vp4g48x49Q0KFil'},
#      'href': 'https://api.spotify.com/v1/albums/1YydmO6Vp4g48x49Q0KFil',
#      'id': '1YydmO6Vp4g48x49Q0KFil',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ead23ab5cb1c1773cc41dd81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ead23ab5cb1c1773cc41dd81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ead23ab5cb1c1773cc41dd81',
#        'width': 64}],
#      'name': '1019',
#      'release_date': '2019-09-27',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1YydmO6Vp4g48x49Q0KFil'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#       'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#       'id': '4LwRgSkj7AJJTKLnEaHjMv',
#       'name': 'Lucio101',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3OSeYeKlvOhNfcLVQNadmB'},
#       'href': 'https://api.spotify.com/v1/artists/3OSeYeKlvOhNfcLVQNadmB',
#       'id': '3OSeYeKlvOhNfcLVQNadmB',
#       'name': 'Omar101',
#       'type': 'artist',
#       'uri': 'spotify:artist:3OSeYeKlvOhNfcLVQNadmB'}],
#     'disc_number': 1,
#     'duration_ms': 129893,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEKF21900888'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/14UUBO41DkFSEA4NoRpFTq'},
#     'href': 'https://api.spotify.com/v1/tracks/14UUBO41DkFSEA4NoRpFTq',
#     'id': '14UUBO41DkFSEA4NoRpFTq',
#     'is_local': False,
#     'is_playable': True,
#     'name': '6 Nullen (feat. Omar101)',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/934983f5d539e2ee7c7e98aeb1b61655951c1c0f?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:14UUBO41DkFSEA4NoRpFTq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#        'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#        'id': '2IVvZIe3P9BMuCI6h48Bjg',
#        'name': 'Nizi19',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1RTQLmrupXVeoHAsTdCA7e'},
#      'href': 'https://api.spotify.com/v1/albums/1RTQLmrupXVeoHAsTdCA7e',
#      'id': '1RTQLmrupXVeoHAsTdCA7e',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737e9c2ffa31f8046ab4f0d76f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027e9c2ffa31f8046ab4f0d76f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517e9c2ffa31f8046ab4f0d76f',
#        'width': 64}],
#      'name': 'Maka Knacker',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1RTQLmrupXVeoHAsTdCA7e'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/34LetYSjEuG2fBb4Z8PwPg'},
#       'href': 'https://api.spotify.com/v1/artists/34LetYSjEuG2fBb4Z8PwPg',
#       'id': '34LetYSjEuG2fBb4Z8PwPg',
#       'name': 'Pashanim',
#       'type': 'artist',
#       'uri': 'spotify:artist:34LetYSjEuG2fBb4Z8PwPg'}],
#     'disc_number': 1,
#     'duration_ms': 181000,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEKF22200382'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0EsbOkROZEauEJL3En3y25'},
#     'href': 'https://api.spotify.com/v1/tracks/0EsbOkROZEauEJL3En3y25',
#     'id': '0EsbOkROZEauEJL3En3y25',
#     'is_local': False,
#     'is_playable': True,
#     'name': '2wasser2sprite (feat. Pashanim)',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bca05b99e039d76b0de0bd6eecb98a7a5d3c829f?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:0EsbOkROZEauEJL3En3y25'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#        'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#        'id': '2IVvZIe3P9BMuCI6h48Bjg',
#        'name': 'Nizi19',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1RTQLmrupXVeoHAsTdCA7e'},
#      'href': 'https://api.spotify.com/v1/albums/1RTQLmrupXVeoHAsTdCA7e',
#      'id': '1RTQLmrupXVeoHAsTdCA7e',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737e9c2ffa31f8046ab4f0d76f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027e9c2ffa31f8046ab4f0d76f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517e9c2ffa31f8046ab4f0d76f',
#        'width': 64}],
#      'name': 'Maka Knacker',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1RTQLmrupXVeoHAsTdCA7e'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#     'disc_number': 1,
#     'duration_ms': 213000,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEKF22200376'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4GZ2jlWi921B8LNsZ8ejQ1'},
#     'href': 'https://api.spotify.com/v1/tracks/4GZ2jlWi921B8LNsZ8ejQ1',
#     'id': '4GZ2jlWi921B8LNsZ8ejQ1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Münzenwerfen',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e892ee3925a11aefc690b4741f1f84d3ffa6a8b9?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4GZ2jlWi921B8LNsZ8ejQ1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#        'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#        'id': '4LwRgSkj7AJJTKLnEaHjMv',
#        'name': 'Lucio101',
#        'type': 'artist',
#        'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#        'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#        'id': '2IVvZIe3P9BMuCI6h48Bjg',
#        'name': 'Nizi19',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1YydmO6Vp4g48x49Q0KFil'},
#      'href': 'https://api.spotify.com/v1/albums/1YydmO6Vp4g48x49Q0KFil',
#      'id': '1YydmO6Vp4g48x49Q0KFil',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ead23ab5cb1c1773cc41dd81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ead23ab5cb1c1773cc41dd81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ead23ab5cb1c1773cc41dd81',
#        'width': 64}],
#      'name': '1019',
#      'release_date': '2019-09-27',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1YydmO6Vp4g48x49Q0KFil'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#       'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#       'id': '4LwRgSkj7AJJTKLnEaHjMv',
#       'name': 'Lucio101',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#     'disc_number': 1,
#     'duration_ms': 194320,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEKF21900885'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5p5sP9mSrjHGvBu575JYLD'},
#     'href': 'https://api.spotify.com/v1/tracks/5p5sP9mSrjHGvBu575JYLD',
#     'id': '5p5sP9mSrjHGvBu575JYLD',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Y-3',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d3130a337c6f672c96badd1344507981febe9608?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:5p5sP9mSrjHGvBu575JYLD'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#        'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#        'id': '4LwRgSkj7AJJTKLnEaHjMv',
#        'name': 'Lucio101',
#        'type': 'artist',
#        'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/00abS2DPkpnDDFfKuh8ivV'},
#      'href': 'https://api.spotify.com/v1/albums/00abS2DPkpnDDFfKuh8ivV',
#      'id': '00abS2DPkpnDDFfKuh8ivV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27392c46822f39f75c417a92959',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0292c46822f39f75c417a92959',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485192c46822f39f75c417a92959',
#        'width': 64}],
#      'name': 'Kaltes Getränk (feat. Nizi19)',
#      'release_date': '2020-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:00abS2DPkpnDDFfKuh8ivV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#       'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#       'id': '4LwRgSkj7AJJTKLnEaHjMv',
#       'name': 'Lucio101',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#     'disc_number': 1,
#     'duration_ms': 136051,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE862000382'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0VH45hSZlgCZpqPcmTEuTP'},
#     'href': 'https://api.spotify.com/v1/tracks/0VH45hSZlgCZpqPcmTEuTP',
#     'id': '0VH45hSZlgCZpqPcmTEuTP',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Kaltes Getränk (feat. Nizi19)',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5af2ebf4c97b780f8ac39c1b7fce13d25104501d?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0VH45hSZlgCZpqPcmTEuTP'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3r82jUxl7ThSdOhB90Qn6u'},
#        'href': 'https://api.spotify.com/v1/artists/3r82jUxl7ThSdOhB90Qn6u',
#        'id': '3r82jUxl7ThSdOhB90Qn6u',
#        'name': '1019',
#        'type': 'artist',
#        'uri': 'spotify:artist:3r82jUxl7ThSdOhB90Qn6u'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#        'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#        'id': '4LwRgSkj7AJJTKLnEaHjMv',
#        'name': 'Lucio101',
#        'type': 'artist',
#        'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#        'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#        'id': '2IVvZIe3P9BMuCI6h48Bjg',
#        'name': 'Nizi19',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4kGYZ5RVyLmbcOTIuPjPZe'},
#      'href': 'https://api.spotify.com/v1/albums/4kGYZ5RVyLmbcOTIuPjPZe',
#      'id': '4kGYZ5RVyLmbcOTIuPjPZe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c99dfbb3cc3b7c4f1804dc9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c99dfbb3cc3b7c4f1804dc9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c99dfbb3cc3b7c4f1804dc9b',
#        'width': 64}],
#      'name': 'Dagobert Duck (feat. Lucio101 & Nizi19)',
#      'release_date': '2021-12-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4kGYZ5RVyLmbcOTIuPjPZe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3r82jUxl7ThSdOhB90Qn6u'},
#       'href': 'https://api.spotify.com/v1/artists/3r82jUxl7ThSdOhB90Qn6u',
#       'id': '3r82jUxl7ThSdOhB90Qn6u',
#       'name': '1019',
#       'type': 'artist',
#       'uri': 'spotify:artist:3r82jUxl7ThSdOhB90Qn6u'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#       'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#       'id': '4LwRgSkj7AJJTKLnEaHjMv',
#       'name': 'Lucio101',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#     'disc_number': 1,
#     'duration_ms': 131820,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEKF22101289'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2BTRtXJHyq3R4caYG6pYtp'},
#     'href': 'https://api.spotify.com/v1/tracks/2BTRtXJHyq3R4caYG6pYtp',
#     'id': '2BTRtXJHyq3R4caYG6pYtp',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Dagobert Duck (feat. Lucio101 & Nizi19)',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d24749b23033ec180de719705d6b014150fef93e?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2BTRtXJHyq3R4caYG6pYtp'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#        'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#        'id': '4LwRgSkj7AJJTKLnEaHjMv',
#        'name': 'Lucio101',
#        'type': 'artist',
#        'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#        'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#        'id': '2IVvZIe3P9BMuCI6h48Bjg',
#        'name': 'Nizi19',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1YydmO6Vp4g48x49Q0KFil'},
#      'href': 'https://api.spotify.com/v1/albums/1YydmO6Vp4g48x49Q0KFil',
#      'id': '1YydmO6Vp4g48x49Q0KFil',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ead23ab5cb1c1773cc41dd81',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ead23ab5cb1c1773cc41dd81',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ead23ab5cb1c1773cc41dd81',
#        'width': 64}],
#      'name': '1019',
#      'release_date': '2019-09-27',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1YydmO6Vp4g48x49Q0KFil'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#       'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#       'id': '4LwRgSkj7AJJTKLnEaHjMv',
#       'name': 'Lucio101',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#     'disc_number': 1,
#     'duration_ms': 197720,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEKF21900880'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7Bz1c1PxIC4v7eSwTWP41t'},
#     'href': 'https://api.spotify.com/v1/tracks/7Bz1c1PxIC4v7eSwTWP41t',
#     'id': '7Bz1c1PxIC4v7eSwTWP41t',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Safe',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/88a275c82fe2fae928cacb41424395ee0567a6c0?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7Bz1c1PxIC4v7eSwTWP41t'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#        'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#        'id': '2IVvZIe3P9BMuCI6h48Bjg',
#        'name': 'Nizi19',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2NKelK5LrcVeYoDdEBVhmm'},
#        'href': 'https://api.spotify.com/v1/artists/2NKelK5LrcVeYoDdEBVhmm',
#        'id': '2NKelK5LrcVeYoDdEBVhmm',
#        'name': 'Karamel19',
#        'type': 'artist',
#        'uri': 'spotify:artist:2NKelK5LrcVeYoDdEBVhmm'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6YlmAPsJFDRmtkO1Tx8Wb2'},
#      'href': 'https://api.spotify.com/v1/albums/6YlmAPsJFDRmtkO1Tx8Wb2',
#      'id': '6YlmAPsJFDRmtkO1Tx8Wb2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ce6cad4e41bced7dc1081b95',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ce6cad4e41bced7dc1081b95',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ce6cad4e41bced7dc1081b95',
#        'width': 64}],
#      'name': 'Pass',
#      'release_date': '2021-01-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6YlmAPsJFDRmtkO1Tx8Wb2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2NKelK5LrcVeYoDdEBVhmm'},
#       'href': 'https://api.spotify.com/v1/artists/2NKelK5LrcVeYoDdEBVhmm',
#       'id': '2NKelK5LrcVeYoDdEBVhmm',
#       'name': 'Karamel19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NKelK5LrcVeYoDdEBVhmm'}],
#     'disc_number': 1,
#     'duration_ms': 163000,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEKF22100004'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1YOjbom11usDpFDWNuX2dM'},
#     'href': 'https://api.spotify.com/v1/tracks/1YOjbom11usDpFDWNuX2dM',
#     'id': '1YOjbom11usDpFDWNuX2dM',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Pass',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4c0467c1f16cf96e804592e26b856e7710edd46d?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1YOjbom11usDpFDWNuX2dM'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#        'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#        'id': '2IVvZIe3P9BMuCI6h48Bjg',
#        'name': 'Nizi19',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1RTQLmrupXVeoHAsTdCA7e'},
#      'href': 'https://api.spotify.com/v1/albums/1RTQLmrupXVeoHAsTdCA7e',
#      'id': '1RTQLmrupXVeoHAsTdCA7e',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737e9c2ffa31f8046ab4f0d76f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027e9c2ffa31f8046ab4f0d76f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517e9c2ffa31f8046ab4f0d76f',
#        'width': 64}],
#      'name': 'Maka Knacker',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1RTQLmrupXVeoHAsTdCA7e'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#       'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#       'id': '4LwRgSkj7AJJTKLnEaHjMv',
#       'name': 'Lucio101',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'}],
#     'disc_number': 1,
#     'duration_ms': 173000,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEKF22200380'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4rJuqXdmRXSOPrVIyvWuVD'},
#     'href': 'https://api.spotify.com/v1/tracks/4rJuqXdmRXSOPrVIyvWuVD',
#     'id': '4rJuqXdmRXSOPrVIyvWuVD',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Usher',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2f157f439a8040028609e4efdd66114980fa33a8?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4rJuqXdmRXSOPrVIyvWuVD'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#        'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#        'id': '4LwRgSkj7AJJTKLnEaHjMv',
#        'name': 'Lucio101',
#        'type': 'artist',
#        'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6rQ7qQZhdNfMxhNGnCirSC'},
#      'href': 'https://api.spotify.com/v1/albums/6rQ7qQZhdNfMxhNGnCirSC',
#      'id': '6rQ7qQZhdNfMxhNGnCirSC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dbc191aa2d23a4d14e590ebb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dbc191aa2d23a4d14e590ebb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dbc191aa2d23a4d14e590ebb',
#        'width': 64}],
#      'name': 'MITTENDRIN',
#      'release_date': '2020-09-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6rQ7qQZhdNfMxhNGnCirSC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LwRgSkj7AJJTKLnEaHjMv'},
#       'href': 'https://api.spotify.com/v1/artists/4LwRgSkj7AJJTKLnEaHjMv',
#       'id': '4LwRgSkj7AJJTKLnEaHjMv',
#       'name': 'Lucio101',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LwRgSkj7AJJTKLnEaHjMv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IVvZIe3P9BMuCI6h48Bjg'},
#       'href': 'https://api.spotify.com/v1/artists/2IVvZIe3P9BMuCI6h48Bjg',
#       'id': '2IVvZIe3P9BMuCI6h48Bjg',
#       'name': 'Nizi19',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IVvZIe3P9BMuCI6h48Bjg'}],
#     'disc_number': 1,
#     'duration_ms': 107913,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE862002002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/099C0a7YMJIudzA3aeUaL9'},
#     'href': 'https://api.spotify.com/v1/tracks/099C0a7YMJIudzA3aeUaL9',
#     'id': '099C0a7YMJIudzA3aeUaL9',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Nix (feat. Nizi19)',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/98bb8a6503eb2ecea5570db99fa86f491619e352?cid=27b10e1918a0404cb6fb89747bc014a9',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:099C0a7YMJIudzA3aeUaL9'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Nizi19&type=track&market=DE&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 138}}
