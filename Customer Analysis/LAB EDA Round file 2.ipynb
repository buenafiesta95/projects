# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 100

# %%
file2 = pd.read_csv('file2.csv')

# %%
ca_df = pd.concat([file2],axis = 1, sort=False)

# %%
def lower_case_column_names(ca_df):
    ca_df.columns=[i.lower() for i in ca_df.columns]
    return ca_df

# %%
lower_case_column_names(ca_df)
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
def rename_columns(ca_df):
    ca_df.rename(columns={'customer':'id','st':'state', 'gender':'gender',"education":"education", "customer lifetime value":"CLV","monthly premium auto": "monthly premium auto","policy type":"policy type", "vehicle class" : "vehicle class", "total claim amount":"total claim amount"}, inplace=True )
    return ca_df

# %%
rename_columns(ca_df)
# Out:
#           id       state gender education          CLV  income  \
# 0    GS98873     Arizona      F  Bachelor   323912.47%   16061
# 1    CW49887  California      F    Master   462680.11%   79487
# 2    MY31220  California      F   College   899704.02%   54230
# 3    UH35128      Oregon      F   College  2580706.30%   71210
# 4    WH52799     Arizona      F   College   380812.21%   94903
# ..       ...         ...    ...       ...          ...     ...
# 991  HV85198     Arizona      M    Master   847141.75%   63513
# 992  BS91566     Arizona      F   College   543121.91%   58161
# 993  IL40123      Nevada      F   College   568964.41%   83640
# 994  MY32149  California      F    Master   368672.38%       0
# 995  SA91515  California      M  Bachelor   399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# 0                      88                    1/0/00          633.600000
# ...

# %%
def drop_columns(ca_df) :
    ca_df.drop(columns=["id"], inplace=True)
    return ca_df

# %%
drop_columns(ca_df)
# Out:
#           state gender education          CLV  income  monthly premium auto  \
# 0       Arizona      F  Bachelor   323912.47%   16061                    88
# 1    California      F    Master   462680.11%   79487                   114
# 2    California      F   College   899704.02%   54230                   112
# 3        Oregon      F   College  2580706.30%   71210                   214
# 4       Arizona      F   College   380812.21%   94903                    94
# ..          ...    ...       ...          ...     ...                   ...
# 991     Arizona      M    Master   847141.75%   63513                    70
# 992     Arizona      F   College   543121.91%   58161                    68
# 993      Nevada      F   College   568964.41%   83640                    70
# 994  California      F    Master   368672.38%       0                    96
# 995  California      M  Bachelor   399258.39%       0                   111
#
# ...

# %%
list(ca_df.columns)
# Out:
# ['state',
#  'gender',
#  'education',
#  'CLV',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'total claim amount',
#  'policy type',
#  'vehicle class']

# %%
ca_df = ca_df [['state',
 'gender',
 'education',
 'CLV',
 'income',
 'monthly premium auto',
 'number of open complaints',
 'policy type',
 'vehicle class',
 'total claim amount']]

# %%
ca_df
# Out:
#           state gender education          CLV  income  monthly premium auto  \
# 0       Arizona      F  Bachelor   323912.47%   16061                    88
# 1    California      F    Master   462680.11%   79487                   114
# 2    California      F   College   899704.02%   54230                   112
# 3        Oregon      F   College  2580706.30%   71210                   214
# 4       Arizona      F   College   380812.21%   94903                    94
# ..          ...    ...       ...          ...     ...                   ...
# 991     Arizona      M    Master   847141.75%   63513                    70
# 992     Arizona      F   College   543121.91%   58161                    68
# 993      Nevada      F   College   568964.41%   83640                    70
# 994  California      F    Master   368672.38%       0                    96
# 995  California      M  Bachelor   399258.39%       0                   111
#
# ...

# %%
ca_df.to_csv("LAB EDA Round file 2.csv", index=False)
