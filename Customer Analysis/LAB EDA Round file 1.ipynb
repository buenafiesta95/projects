# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 100

# %%
file1 = pd.read_csv('file1.csv')

# %%
ca_df = pd.concat([file1],axis = 1, sort=False)

# %%
def lower_case_column_names(ca_df):
    ca_df.columns=[i.lower() for i in ca_df.columns]
    return ca_df

# %%
lower_case_column_names(ca_df)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def rename_columns(ca_df):
    ca_df.rename(columns={'customer':'id','st':'state', 'gender':'gender',"education":"education", "customer lifetime value":"CLV","monthly premium auto": "monthly premium auto","policy type":"policy type", "vehicle class" : "vehicle class", "total claim amount":"total claim amount"}, inplace=True )
    return ca_df

# %%
rename_columns(ca_df)
# Out:
#            id       state gender             education          CLV   income  \
# 0     RB50392  Washington    NaN                Master          NaN      0.0
# 1     QZ44356     Arizona      F              Bachelor   697953.59%      0.0
# 2     AI49188      Nevada      F              Bachelor  1288743.17%  48767.0
# 3     WW63253  California      M              Bachelor   764586.18%      0.0
# 4     GA49547  Washington      M  High School or Below   536307.65%  36357.0
# ...       ...         ...    ...                   ...          ...      ...
# 4003      NaN         NaN    NaN                   NaN          NaN      NaN
# 4004      NaN         NaN    NaN                   NaN          NaN      NaN
# 4005      NaN         NaN    NaN                   NaN          NaN      NaN
# 4006      NaN         NaN    NaN                   NaN          NaN      NaN
# 4007      NaN         NaN    NaN                   NaN          NaN      NaN
#
# ...

# %%
def drop_columns(ca_df) :
    ca_df.drop(columns=["id"], inplace=True)
    return ca_df

# %%
drop_columns(ca_df)
# Out:
#            state gender             education          CLV   income  \
# 0     Washington    NaN                Master          NaN      0.0
# 1        Arizona      F              Bachelor   697953.59%      0.0
# 2         Nevada      F              Bachelor  1288743.17%  48767.0
# 3     California      M              Bachelor   764586.18%      0.0
# 4     Washington      M  High School or Below   536307.65%  36357.0
# ...          ...    ...                   ...          ...      ...
# 4003         NaN    NaN                   NaN          NaN      NaN
# 4004         NaN    NaN                   NaN          NaN      NaN
# 4005         NaN    NaN                   NaN          NaN      NaN
# 4006         NaN    NaN                   NaN          NaN      NaN
# 4007         NaN    NaN                   NaN          NaN      NaN
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
list(ca_df.columns)
# Out:
# ['state',
#  'gender',
#  'education',
#  'CLV',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
ca_df = ca_df [['state',
 'gender',
 'education',
 'CLV',
 'income',
 'monthly premium auto',
 'number of open complaints',
 'policy type',
 'vehicle class',
 'total claim amount']]

# %%
ca_df
# Out:
#            state gender             education          CLV   income  \
# 0     Washington    NaN                Master          NaN      0.0
# 1        Arizona      F              Bachelor   697953.59%      0.0
# 2         Nevada      F              Bachelor  1288743.17%  48767.0
# 3     California      M              Bachelor   764586.18%      0.0
# 4     Washington      M  High School or Below   536307.65%  36357.0
# ...          ...    ...                   ...          ...      ...
# 4003         NaN    NaN                   NaN          NaN      NaN
# 4004         NaN    NaN                   NaN          NaN      NaN
# 4005         NaN    NaN                   NaN          NaN      NaN
# 4006         NaN    NaN                   NaN          NaN      NaN
# 4007         NaN    NaN                   NaN          NaN      NaN
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
ca_df.to_csv("LAB EDA Round file 1.csv", index=False)
